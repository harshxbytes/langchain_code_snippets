# %%
import os 
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI( model = "gemini-2.5-flash")
model
# Out:
# ChatGoogleGenerativeAI(output_version=None, profile={'name': 'Gemini 2.5 Flash', 'release_date': '2025-03-20', 'last_updated': '2025-06-05', 'open_weights': False, 'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), location=None, model='gemini-2.5-flash', client=<google.genai.client.Client object at 0x0000022FE7778170>, default_metadata=(), model_kwargs={})

# %%
response = model.invoke("hello , how r you?")
response.content
# Out:
# "Hello! I'm doing well, thank you for asking! How are you doing today?"

# %%
import os 
from langchain.chat_models import init_chat_model
os.environ["GROQ_API"] = os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:Llama 3.3 70B")
response = model.invoke("5 nicknames for harsh")
response.content
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[37], line 6
#       2 from langchain.chat_models import init_chat_model
#       3 os.environ["GROQ_API"] = os.getenv("GROQ_API_KEY")
#       4
#       5 model = init_chat_model("groq:Llama 3.3 70B")
# ----> 6 response = model.invoke("5 nicknames for harsh")
#       7 response.content
#
# File c:\Users\Harsh Rajput\Desktop\codes\learning rag and lagchain + langgraph\day1\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# ...

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model(
    "groq:llama-3.3-70b-versatile"
)

response = model.invoke("5 nicknames for Harsh")

print(response.content)

# %%
from langchain.tools import tool

@tool
def get_weather(location : str) -> str:
    """ get the weather at a location """
    return f"it's sunnyy in {location}"

model_with_tools = model.bind_tools([get_weather])

# %%
response = model_with_tools.invoke("what's the weather like in boston")

for tools_call in response.tool_calls:
    print(f"tools: {tool_call['name']}")
    print(f"args : {tool_call['args']}")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 response = model_with_tools.invoke("what's the weather like in boston")
#       2
#       3 for tools_call in response.tool_calls:
#       4     print(f"tools: {tool_call['name']}")
#
# File c:\Users\Harsh Rajput\Desktop\codes\learning rag and lagchain + langgraph\day1\.venv\Lib\site-packages\langchain_core\runnables\base.py:5881, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5874 @override
#    5875 def invoke(
#    5876     self,
#    (...)   5879     **kwargs: Any | None,
#    5880 ) -> Output:
# -> 5881     return self.bound.invoke(
#    5882         input,
#    5883         self._merge_configs(config),
#    5884         **{**self.kwargs, **kwargs},
#    5885     )
#
# ...

# %%
messages = [{"role" : "user" , "content": "what's the weather in boston"}]
ai_msg = model_with_tools.invoke(messages)
messages.append(ai_msg)

for tool_call in ai_msg.tool_calls:
    tool_result = get_weather.invoke(tool_call)
    messages.append(tool_result)

final_response = model_with_tools.invoke(messages)
print(final_response.text)

# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GROQ_API"] = os.getenv("GROQ_API_KEY")
model = init_chat_model(
    "groq:llama-3.3-70b-versatile"
)

model
# Out:
# ChatGroq(output_version=None, profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x000002A771FEA630>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000002A771BD9AF0>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)
